# %% [markdown]
# # Carsh Course Review Exercises

# %% [markdown]
# ### import numpy.pandas,matplotlib and sklearn also set visualization to be shown

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(101)

# %%
data=np.random.randint(1,101,(100,5))

# %%
data
# Out:
# array([[ 44,  47,  95,  69,  56],
#        [ 70,  42,  42,  15,  48],
#        [  4,  65,  24,  81,  43],
#        [ 85,  89,  90,  11,  79],
#        [ 98,  66,   9,  15,  29],
#        [ 81,  18,  63,  28,  34],
#        [ 15,  22,  26,  97,  65],
#        [ 85,   7,  77,  96,  44],
#        [ 95,  41,  69,  46,  25],
#        [ 51,  37,  63,  53,  10],
#        [ 80,  75,  31,  71,  91],
#        [ 59,  98,  58,  61,  65],
#        [ 87,  94,  32,  23,  91],
#        [  4,  53,  10,  94,  61],
#        [ 43,   2,  16,  39,  66],
#        [ 11,  87,  64,  99,  12],
#        [ 97,  68,  96,  95,  81],
#        [ 17,  31,  90,  63,  63],
#        [ 43,  11,  49,  87,  34],
#        [ 53,  25,  95,  79,  72],
#        [ 20,  76,  82,  72,  24],
#        [ 94,  59,  49,  77,  64],
#        [ 59,  29,  85,  48,  41],
#        [ 64,  47,  23,   7,  11],
#        [ 62,  16,  32,  24,  17],
#        [ 96,  27,  91,  16,  95],
#        [ 43,  66,  22,  35,  27],
# ...

# %%
# %matplotlib inline
plt.imshow(data,aspect=0.05)
plt.colorbar()
plt.title('My plot')
# Out:
# Text(0.5,1,'My plot')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_model=MinMaxScaler()

# %%
scaler_model.fit(data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler_model.transform(data)
# Out:
# array([[0.85263158, 0.17171717, 0.59183673, 0.65263158, 0.44210526],
#        [0.01052632, 0.51515152, 0.48979592, 0.75789474, 0.84210526],
#        [0.35789474, 0.53535354, 0.93877551, 0.74736842, 0.03157895],
#        [0.35789474, 0.56565657, 0.34693878, 0.13684211, 0.4       ],
#        [0.41052632, 0.71717172, 0.36734694, 0.46315789, 0.72631579],
#        [0.92631579, 0.97979798, 0.35714286, 0.43157895, 0.26315789],
#        [0.66315789, 0.57575758, 0.02040816, 0.55789474, 0.71578947],
#        [0.4       , 0.67676768, 0.7244898 , 0.90526316, 0.68421053],
#        [0.75789474, 0.6969697 , 0.92857143, 0.18947368, 0.13684211],
#        [0.56842105, 0.09090909, 0.69387755, 1.        , 0.93684211],
#        [0.50526316, 0.54545455, 0.44897959, 0.37894737, 0.13684211],
#        [0.41052632, 0.61616162, 0.07142857, 0.01052632, 0.90526316],
#        [0.72631579, 0.41414141, 0.23469388, 0.95789474, 0.27368421],
#        [0.96842105, 0.43434343, 0.47959184, 0.70526316, 0.42105263],
# ...

# %%
data =pd.DataFrame(data=data,columns=['f1','f2','f3','f4','f5'])

# %%
data
# Out:
#     f1  f2  f3  f4  f5
# 0   44  47  95  69  56
# 1   70  42  42  15  48
# 2    4  65  24  81  43
# 3   85  89  90  11  79
# 4   98  66   9  15  29
# 5   81  18  63  28  34
# 6   15  22  26  97  65
# 7   85   7  77  96  44
# 8   95  41  69  46  25
# 9   51  37  63  53  10
# 10  80  75  31  71  91
# 11  59  98  58  61  65
# 12  87  94  32  23  91
# 13   4  53  10  94  61
# 14  43   2  16  39  66
# 15  11  87  64  99  12
# 16  97  68  96  95  81
# 17  17  31  90  63  63
# 18  43  11  49  87  34
# 19  53  25  95  79  72
# 20  20  76  82  72  24
# 21  94  59  49  77  64
# 22  59  29  85  48  41
# 23  64  47  23   7  11
# 24  62  16  32  24  17
# 25  96  27  91  16  95
# 26  43  66  22  35  27
# 27  82  80  30  64  31
# 28  93  99  74  43  14
# 29  28  77   1  86  69
# ..  ..  ..  ..  ..  ..
# 70  76  84  11  72  28
# 71  57  94  81  98  71
# 72  96  78  71  92  97
# 73  12  14  95  37  13
# 74  48  61  38   7   4
# 75  83  40  53  10  64
# 76  77  49  95  59  76
# 77  96  92  25  11   1
# ...

# %%
data.plot(y=['f1','f2','f3','f4','f5'])

# %%
data.plot(x=0,y=2,kind='scatter')

# %%
x=data[['f1','f2','f3','f4']]

# %%
y=data['f5']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      f1  f2  f3  f4
# 55   78  48  70  58
# 88   22  62  62  41
# 26   43  66  22  35
# 42  100  37  78  91
# 69   56  67  96  97
# 15   11  87  64  99
# 40   57  88  19  33
# 96   65  34  89  38
# 9    51  37  63  53
# 72   96  78  71  92
# 11   59  98  58  61
# 47   64  44  47  51
# 85   62  34  26  24
# 28   93  99  74  43
# 93   27  92  64  12
# 5    81  18  63  28
# 66   54  18  90  16
# 65   38  16  92  79
# 35    8  67  62   3
# 16   97  68  96  95
# 49    2  99  17  36
# 34   64  15  54  69
# 7    85   7  77  96
# 95   32   8  65  42
# 27   82  80  30  64
# 19   53  25  95  79
# 81   51  99  47  31
# 25   96  27  91  16
# 62   78  65  38  66
# 13    4  53  10  94
# ..  ...  ..  ..  ..
# 79   55  62   1  16
# 41   75  13  87  17
# 58   39  30  39  84
# 48   77  96  51  54
# 98   80  24  88  36
# 57   19  43  80  56
# 75   83  40  53  10
# 32   80  86  39  66
# 94    2  24  88  53
# 59   74  26  21  88
# 63   73  94  69   6
# 84   42  61  15  48
# 37    9  88  53  16
# ...

# %%
x_test
# Out:
#     f1  f2  f3  f4
# 83  64  43  94  99
# 53  16  19   7  30
# 70  76  84  11  72
# 45  43  83  12  32
# 44  95  35   5  38
# 39  56  26  65  91
# 22  59  29  85  48
# 80  47  90  39  16
# 10  80  75  31  71
# 0   44  47  95  69
# 18  43  11  49  87
# 30  99  53  24  15
# 73  12  14  95  37
# 33  51  89  64  88
# 90  39  97  68  17
# 4   98  66   9  15
# 76  77  49  95  59
# 77  96  92  25  11
# 12  87  94  32  23
# 31  26  19  17  63

# %%
y_train
# Out:
# 55    43
# 88    75
# 26    27
# 42    61
# 69    66
# 15    12
# 40    32
# 96    92
# 9     10
# 72    97
# 11    65
# 47    38
# 85    74
# 28    14
# 93    19
# 5     34
# 66    16
# 65    73
# 35    16
# 16    81
# 49    22
# 34    98
# 7     44
# 95    24
# 27    31
# 19    72
# 81    70
# 25    95
# 62    44
# 13    61
#       ..
# 79    81
# 41    51
# 58    35
# 48     7
# 98    54
# 57    66
# 75    64
# 32    48
# 94    17
# 59    13
# 63     8
# 84    25
# 37    94
# 29    69
# 1     48
# 52    65
# 21    64
# 2     43
# 23    11
# 87    58
# 91    72
# 74     4
# 86    97
# 82    66
# 20    24
# 60    38
# 71    71
# 14    66
# 92    70
# 51    83
# Name: f5, Length: 80, dtype: int32

# %%
x_train.plot()

# %%
y_train.plot()

# %%
y_test.plot()
